# %% [markdown]
# ## Data Reading

# %%
df=spark.read.table('databricks_cata.bronze.regions')

# %% [markdown]
# ## Drop columns

# %%
df=df.drop("_rescued_data")

# %% [markdown]
# ## Data Writing

# %%
df.write.format('delta').mode('append').save("abfss://silver2026@storagespotifyproject20.dfs.core.windows.net/regions")

# %% [markdown]
# ## Creating table for silver layer

# %%
# %sql
create table if not exists databricks_cata.silver.Regions_silver
using delta
location 'abfss://silver2026@storagespotifyproject20.dfs.core.windows.net/regions'
