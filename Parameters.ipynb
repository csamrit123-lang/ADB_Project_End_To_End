# %%
dataset=[
    {
        "file_name" : "orders"
    },
    {
        "file_name" : "products"
    },
    {
        "file_name" : "customers"
    }
]

# %%
dbutils.jobs.taskValues.set('output_datasets',dataset)
